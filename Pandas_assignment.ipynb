# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilcn-ec/Machine_learning/blob/main/Pandas_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas

# %%
import pandas as pd

df=pd.read_csv('/content/Pandas_data.csv')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
df.size
# Out:
# 676

# %%
df.shape
# Out:
# (169, 4)

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
print(df.at[2,'Pulse'])
# Out:
# 103

# %%
print( df.iat[2,1] )
# Out:
# 103

# %%
print(  df.loc[:,'Pulse'])
# Out:
# 0      110
# 1      117
# 2      103
# 3      109
# 4      117
#       ...
# 164    105
# 165    110
# 166    115
# 167    120
# 168    125
# Name: Pulse, Length: 169, dtype: int64

# %%
print(df.loc[:,['Pulse','Duration']])
# Out:
#      Pulse  Duration
# 0      110        60
# 1      117        60
# 2      103        60
# 3      109        45
# 4      117        45
# ..     ...       ...
# 164    105        60
# 165    110        60
# 166    115        60
# 167    120        75
# 168    125        75
#
# [169 rows x 2 columns]

# %%
print(df.iloc[:,-1])
# Out:
# 0      409.1
# 1      479.0
# 2      340.0
# 3      282.4
# 4      406.0
#        ...
# 164    290.8
# 165    300.0
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64

# %%
print(df.iloc[:,:-1])
# Out:
#      Duration  Pulse  Maxpulse
# 0          60    110       130
# 1          60    117       145
# 2          60    103       135
# 3          45    109       175
# 4          45    117       148
# ..        ...    ...       ...
# 164        60    105       140
# 165        60    110       145
# 166        60    115       145
# 167        75    120       150
# 168        75    125       150
#
# [169 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.max()
# Out:
# Duration     300.0
# Pulse        159.0
# Maxpulse     184.0
# Calories    1860.4
# dtype: float64

# %%
df.min()
# Out:
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.3
# dtype: float64

# %%
df.mean()
# Out:
# Duration     63.846154
# Pulse       107.461538
# Maxpulse    134.047337
# Calories    375.790244
# dtype: float64

# %%
df['Pulse'].unique()
# Out:
# array([110, 117, 103, 109, 102, 104,  98, 100, 106,  90,  97, 108, 130,
#        105,  92, 101,  93, 107, 114, 111,  99, 123, 118, 136, 121, 115,
#        153, 159, 149, 151, 129,  83,  80, 150,  95, 152, 137, 124, 116,
#        112, 119, 113, 141, 122,  85, 120, 125])

# %%
df['Pulse'].nunique()
# Out:
# 47

# %%
df.value_counts()
# Out:
# Duration  Pulse  Maxpulse  Calories
# 60        100    120       300.0       3
#           109    153       387.6       2
#           102    127       300.0       2
# 45        100    120       225.3       2
#           90     112       180.1       2
#                                       ..
# 180       101    127       600.1       1
# 210       108    160       1376.0      1
#           137    184       1860.4      1
# 270       100    131       1729.0      1
# 300       108    143       1500.2      1
# Name: count, Length: 157, dtype: int64

# %%
r1=df.iloc[:,0]
r2=df.iloc[:,1]
r12=pd.concat([r1,r2],axis=1)
print(r12)
# Out:
#      Duration  Pulse
# 0          60    110
# 1          60    117
# 2          60    103
# 3          45    109
# 4          45    117
# ..        ...    ...
# 164        60    105
# 165        60    110
# 166        60    115
# 167        75    120
# 168        75    125
#
# [169 rows x 2 columns]

# %%
r21=pd.concat([r2,r1]).drop_duplicates()
r21
# Out:
# 0      110
# 1      117
# 2      103
# 3      109
# 5      102
# 7      104
# 9       98
# 11     100
# 12     106
# 17      90
# 19      97
# 20     108
# 22     130
# 23     105
# 26      92
# 32     101
# 33      93
# 34     107
# 35     114
# 43     111
# 45      99
# 51     123
# 53     118
# 54     136
# 55     121
# 57     115
# 58     153
# 80     159
# 81     149
# 85     151
# 88     129
# 89      83
# 93      80
# 94     150
# 96      95
# 97     152
# 109    137
# 112    124
# 116    116
# 120    112
# 122    119
# 138    113
# 139    141
# 143    122
# 160     85
# 167    120
# 168    125
# 0       60
# 3       45
# 8       30
# 58      20
# 60     210
# 61     160
# 65     180
# 69     300
# 79     270
# 93      15
# 97      25
# 167     75
# dtype: int64

# %%
r12.to_csv('exp.csv',index=False)

# %%
r12.to_hdf('samp.h5',key='r12',mode='w')

# %%
r12.to_json('sampjson.json',orient='records',lines=True)

# %%
r12.to_excel('sampexl.xlsx',index=False)
